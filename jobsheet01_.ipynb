# %% [markdown]
# <a href="https://colab.research.google.com/github/sanggaasmara/PCVK_Genap_2022/blob/main/jobsheet01_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/777"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan dalam list
for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image,image_2))
  cv2_imshow(final_frame)
  print('\n')

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi,"x",lebar)
cv2_imshow(image_2)

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [0,0,0]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x388 at 0x7F7DC5441F10>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# - Karena google colab dibutuhkan dalam lingkungan AI serta dapat mengeksekusi, menulis, menyimpan kode
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# - Numpy: untuk memanipulasi array digunakan untuk linear elgreba
#
#   Pandas: library untuk memanipulasi data dan data analisis
#
#   cv2: library untuk tugas visi komputer
#
#   Skimage: library untuk mendukung pemrosesan image di python
#
#   Matplotlib: library yang menghasilkan angka dan punya toolkit antarmuka pengguna
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# - berfungsi untuk merubah ukuran menjadi setengah dari ukuran aslinya, jika tidak dilakukan maka gambar akan berukuran seperti aslinya
#
# 4. Perhatikan potongan kode progam berikut :
# Apakah kegunaan kode [0,0,0] ? Jelaskan!
# - berfungsi untuk merubah warna
#
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun
# rendah!
# - dengan semakin tingginya resolusi maka semakin bagus kualitas gambarnya. Resolusi adalah jumlah pixel

# %% [markdown]
# Soal

# %% [markdown]
# 1

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

image_3 = cv.line(image_3,(200,0), (200,tinggi), (0, 0, 0))


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x388 at 0x7F7DC5443A10>

# %% [markdown]
# 2

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

image_3 = cv.line(image_3,(0,0), (lebar,tinggi), (0, 0, 0))
image_3 = cv.line(image_3,(0,tinggi), (lebar,0), (0, 0, 0))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x388 at 0x7F7DC4B31350>
